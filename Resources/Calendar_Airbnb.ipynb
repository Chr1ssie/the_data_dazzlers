# %% [markdown]
# ## This code will extract .gz file

# %%
import gzip
import shutil
with gzip.open('extract.csv.gz', 'rb') as f_in:
    with open('calendar.csv', 'wb') as f_out:
        shutil.copyfileobj(f_in, f_out)

# %% [markdown]
# ## This code cuts up csv to 15 chops

# %%
import pandas as pd

# %%
df=pd.read_csv("calendar.csv")
df

# %%
import numpy as np

# %%
df_list=np.array_split(df,15)

# %%
for i in range(15):
    df_list[i].to_csv(f"./calendardata/calendar_{i+1}.csv",index=False)

# %% [markdown]
# ## code below will reasample data into a single data frame

# %%
import os
import glob
import pandas as pd

os.chdir("calendardata")

files = glob.glob('*.csv')

combined_csv = pd.concat([pd.read_csv(file) for file in files ]).reset_index()
combined_csv
# Out:
# C:\Users\polska2207\AppData\Local\Temp\ipykernel_12384\4006804175.py:9: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_csv = pd.concat([pd.read_csv(file) for file in files ]).reset_index()
# C:\Users\polska2207\AppData\Local\Temp\ipykernel_12384\4006804175.py:9: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_csv = pd.concat([pd.read_csv(file) for file in files ]).reset_index()
# C:\Users\polska2207\AppData\Local\Temp\ipykernel_12384\4006804175.py:9: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_csv = pd.concat([pd.read_csv(file) for file in files ]).reset_index()
# C:\Users\polska2207\AppData\Local\Temp\ipykernel_12384\4006804175.py:9: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
# ...
